# %% [markdown]
# # Exercise 1: 3D Sensors and Point Clouds
# **Modul:** MSR-02/M-05 – Mobile Sensing/ 3D Mapping
# **Tutor:** M.Sc. Felix Esser, M.Sc. Manuel Mittelstedt
# **Release Date:** 30.04.2026
# **Submission deadline:** 09.06.2025 23:59

# %% [markdown]
# ## Goals
#
# * Understanding the working principles of 3D sensors and influences on measurement errors.
# * Learn to process and compare point clouds. Getting a sense of how the properties of point clouds from various sensors differ.
#
# __Maximum points: 35P__

# %% [markdown]
# ## I. Questions (10P)

# %% [markdown]
# * Q1: Name the two most important measuring principles for measuring 3D and briefly explain both. (2P)

# %% [markdown]
# <p style="color: green;">Write your answer here:</p>

# %% [markdown]
# * Q2: Explain the main components and the working principle of a laser scanner. Present the three main axes of a laser scanner and explain their geometric relationship. (2P)

# %% [markdown]
# <p style="color: green;">Write your answer here:</p>

# %% [markdown]
# * Q3: Is the accuracy of a reflectorless EDM measurement influenced by the object to be measured and if so, name the object attributes that influence the measurement?  (2P)

# %% [markdown]
# <p style="color: green;">Write your answer here:</p>

# %% [markdown]
# * Q4: What are “mixed pixels”? Where and why does the effect occur?  (2P)

# %% [markdown]
# <p style="color: green;">Write your answer here:</p>

# %% [markdown]
# * Q5: What are features in the context of point clouds? Name at least two and explain them in a few words. (2P)

# %% [markdown]
# <p style="color: green;">Write your answer here:</p>

# %% [markdown]
# ## II. Coding (20P)

# %% [markdown]
# Two point clouds are provided for the second part of this exercise. A model duck made of clay was measured with a measuring arm using a laser triangulation scanner. In addition, a point cloud was calculated from a large number of images.

# %%
# Note: open3D requires python 3.8, 3.9, 3.10, 3.11 or 3.12
# Check your python version with:
# python --version

# %pip install open3d matplotlib

import numpy as np
import open3d as o3d
import matplotlib.pyplot as plt
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# __Data__
#
# * https://uni-bonn.sciebo.de/s/sgyMge8rSSUKMLm

# %% [markdown]
# __2.1 Initialize Point Clouds__ (5P)

# %% [markdown]
# Initialize the data as open3d point cloud objects (https://www.open3d.org/docs/release/python_api/open3d.geometry.PointCloud.html) and visualize both point clouds.

# %%
# load data
# Info: first column -> x; second column -> y; third column -> z; The coordinates are given in mm
laser = np.loadtxt("data/duck_laserPC.txt")
camera = np.loadtxt("data/duck_cameraPC.txt")

# Initialize open3d point cloud objects
# @TODO Write your code below:


# Visualize point clouds
# @TODO Write your code below:

# %% [markdown]
# Describe the two point clouds. Is the fine structure of the surface visible in both point clouds? What is the noise behavior of the point clouds? Are there any outliers?

# %% [markdown]
# <p style="color: green;">Write your answer here:</p>

# %% [markdown]
# __2.2 Colored Camera Point Cloud__ (3P)
# Since the camera point cloud is calculated from images, RGB values are assigned to each point. Use the color values to visualize a colored point cloud.

# %%
# @TODO Write your code below:
# Info: The RGB values are in the last three columns of the matrix "camera"

# %% [markdown]
# __2.3 Point to Point Distance__ (4P)
# To better compare two point clouds, the point-to-point distance from the camera to the triangulation scanner point cloud should be calculated. Function compute_point_cloud_distance() of the pointcloud class can be used for this purpose. Use the calculated distances to color the points of the camera point cloud.

# %%
# @TODO Write your code below:

# %% [markdown]
# __2.4 Outlier Filter__ (8P)
# The calculated distances can be used to implement an outlier filter. Define a reasonable threshold for the distance and remove all points from the camera point cloud that exceed this distance threshold to the point cloud of the triangulation scanner. Visualize the result by plotting the points that are removed in red and the points that are kept in green.

# %%
# @TODO Write your code below:

# %% [markdown]
# Explain your choice of threshold. Which problems occur with this type of outlier filter and the given data?

# %% [markdown]
# <p style="color: green;">Write your answer here:</p>

# %% [markdown]
# Recompute the distances between the filtered camera point cloud and the triangulation scanner point cloud. Visualize the distances with a histogram.

# %%
# @TODO Write your code below:

# %% [markdown]
# Explain why the histogram only shows positive distances? Is there a way to take the direction of the distance into account, what is the requirement for this?

# %% [markdown]
# <p style="color: green;">Write your answer here:</p>
